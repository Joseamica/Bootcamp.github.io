# %% [markdown]
# #### groupby, sort, averages, count

# %% [markdown]
# ### Ejercicio
# #https://pynative.com/python-pandas-exercise/

# %%
import pandas as pd
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv("Automobile_data.csv", delimiter=",")

# %%
df
# Out:
#             index        company   body-style  wheel-base  length engine-type  \
# 1900-01-30      0    alfa-romero  convertible        88.6   168.8        dohc
# 1900-01-31      1    alfa-romero  convertible        88.6   168.8        dohc
# 1900-02-01      2    alfa-romero    hatchback        94.5   171.2        ohcv
# 1900-02-02      3           audi        sedan        99.8   176.6         ohc
# 1900-02-03      4           audi        sedan        99.4   176.6         ohc
# 1900-02-04      5           audi        sedan        99.8   177.3         ohc
# 1900-02-05      6           audi        wagon       105.8   192.7         ohc
# 1900-02-06      9            bmw        sedan       101.2   176.8         ohc
# 1900-02-07     10            bmw        sedan       101.2   176.8         ohc
# 1900-02-08     11            bmw        sedan       101.2   176.8         ohc
# 1900-02-09     13            bmw        sedan       103.5   189.0         ohc
# ...

# %%
#most expensive car company name
maxPrice = df['price'].max()
maxPrice
# Out:
# 45400.0

# %%
#print all toyota car details
cars = df.groupby('company')
toyota = cars.get_group('toyota')
toyota
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %%
#count total cars per company
total_cars = df['company'].value_counts()
total_cars
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# mitsubishi       4
# audi             4
# mercedes-benz    4
# volkswagen       4
# honda            3
# jaguar           3
# isuzu            3
# alfa-romero      3
# porsche          3
# chevrolet        3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
#find each company highest price car
cars = df.groupby('company')
price_company = cars['company','price'].max()
price_company.head(5)
# Out:
#                  company    price
# company
# alfa-romero  alfa-romero  16500.0
# audi                audi  18920.0
# bmw                  bmw  41315.0
# chevrolet      chevrolet   6575.0
# dodge              dodge   6377.0

# %%
#find all average mileage of each car making company
cars = df.groupby('company')
avg = cars['company','average-mileage'].mean()
avg.head(5)
# Out:
#              average-mileage
# company
# alfa-romero        20.333333
# audi               20.000000
# bmw                19.000000
# chevrolet          41.000000
# dodge              31.000000

# %%
#sort all cars by price columns
price = df.sort_values(by=['price','horsepower'], ascending=False)
price.head(5)
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 46     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# 11              six         182               16  41315.0
# 34            eight         184               14  40960.0
# 46              six         207               17  37028.0
# 12              six         182               15  36880.0

# %%
t = df[['index','company']]
t.head()
# Out:
#    index      company
# 0      0  alfa-romero
# 1      1  alfa-romero
# 2      2  alfa-romero
# 3      3         audi
# 4      4         audi

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
carsDf1 = pd.DataFrame.from_dict(GermanCars)
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
carsDf2 = pd.DataFrame.from_dict(japaneseCars)
carsDf = pd.concat([carsDf1, carsDf2], keys=["Germany", "Japan"])
carsDf
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
carPriceDf = pd.DataFrame.from_dict(Car_Price)
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
carsHorsepowerDf = pd.DataFrame.from_dict(car_Horsepower)
carsDf = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
carsDf
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %%
df.shape
# Out:
# (61, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
# index               61 non-null int64
# company             61 non-null object
# body-style          61 non-null object
# wheel-base          61 non-null float64
# length              61 non-null float64
# engine-type         61 non-null object
# num-of-cylinders    61 non-null object
# horsepower          61 non-null int64
# average-mileage     61 non-null int64
# price               58 non-null float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.8+ KB

# %%
df[col]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-157-25e4ec9abad7> in <module>
# ----> 1 df[col]
#
# NameError: name 'col' is not defined

# %%
df.apply(pd.Series.value_counts).head(5)
# Out:
#    index  company  body-style  wheel-base  length  engine-type  \
# 0    1.0      NaN         NaN         NaN     NaN          NaN
# 1    1.0      NaN         NaN         NaN     NaN          NaN
# 2    1.0      NaN         NaN         NaN     NaN          NaN
# 3    1.0      NaN         NaN         NaN     NaN          NaN
# 4    1.0      NaN         NaN         NaN     NaN          NaN
#
#    num-of-cylinders  horsepower  average-mileage  price
# 0               NaN         NaN              NaN    NaN
# 1               NaN         NaN              NaN    NaN
# 2               NaN         NaN              NaN    NaN
# 3               NaN         NaN              NaN    NaN
# 4               NaN         NaN              NaN    NaN

# %%
df.groupby('body-style').count()
# Out:
#              index  company  wheel-base  length  engine-type  \
# body-style
# convertible      3        3           3       3            3
# hardtop          2        2           2       2            2
# hatchback       15       15          15      15           15
# sedan           32       32          32      32           32
# wagon            9        9           9       9            9
#
#              num-of-cylinders  horsepower  average-mileage  price
# body-style
# convertible                 3           3                3      3
# hardtop                     2           2                2      2
# hatchback                  15          15               15     14
# sedan                      32          32               32     30
# wagon                       9           9                9      9

# %%
df.head(2)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0

# %%
s = pd.Series([2,3,4,5,6])
s
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
random = pd.DataFrame(np.random.rand(20000,5))
random.head(5)
# Out:
#           0         1         2         3         4
# 0  0.878993  0.713328  0.513437  0.041162  0.830877
# 1  0.892765  0.495829  0.211924  0.715137  0.966248
# 2  0.256310  0.586782  0.697543  0.108950  0.319804
# 3  0.781055  0.061966  0.275580  0.964388  0.039140
# 4  0.540734  0.782571  0.123131  0.790131  0.466728

# %%
s1 = pd.Series(random[2]).head(5)
s1
# Out:
# 0    0.513437
# 1    0.211924
# 2    0.697543
# 3    0.275580
# 4    0.123131
# Name: 2, dtype: float64

# %%
random.iloc[2] #agarra los rows y los pone como df
# Out:
# 0    0.256310
# 1    0.586782
# 2    0.697543
# 3    0.108950
# 4    0.319804
# Name: 2, dtype: float64

# %%
random.iloc[-1]
# Out:
# 0    0.964991
# 1    0.006557
# 2    0.752820
# 3    0.162460
# 4    0.199861
# Name: 19999, dtype: float64

# %%
df.loc[0:100]
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# ...

# %%
df.index = pd.date_range('1900/1/30', periods=df.shape[0])

# %%
df.index
# Out:
# DatetimeIndex(['1900-01-30', '1900-01-31', '1900-02-01', '1900-02-02',
#                '1900-02-03', '1900-02-04', '1900-02-05', '1900-02-06',
#                '1900-02-07', '1900-02-08', '1900-02-09', '1900-02-10',
#                '1900-02-11', '1900-02-12', '1900-02-13', '1900-02-14',
#                '1900-02-15', '1900-02-16', '1900-02-17', '1900-02-18',
#                '1900-02-19', '1900-02-20', '1900-02-21', '1900-02-22',
#                '1900-02-23', '1900-02-24', '1900-02-25', '1900-02-26',
#                '1900-02-27', '1900-02-28', '1900-03-01', '1900-03-02',
#                '1900-03-03', '1900-03-04', '1900-03-05', '1900-03-06',
#                '1900-03-07', '1900-03-08', '1900-03-09', '1900-03-10',
#                '1900-03-11', '1900-03-12', '1900-03-13', '1900-03-14',
#                '1900-03-15', '1900-03-16', '1900-03-17', '1900-03-18',
#                '1900-03-19', '1900-03-20', '1900-03-21', '1900-03-22',
# ...

# %%
df.head(5)
df[df['horsepower'] > 200]
# Out:
#             index      company   body-style  wheel-base  length engine-type  \
# 1900-01-30      0  alfa-romero  convertible        88.6   168.8        dohc
# 1900-01-31      1  alfa-romero  convertible        88.6   168.8        dohc
# 1900-02-01      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 1900-02-02      3         audi        sedan        99.8   176.6         ohc
# 1900-02-03      4         audi        sedan        99.4   176.6         ohc
#
#            num-of-cylinders  horsepower  average-mileage    price
# 1900-01-30             four         111               21  13495.0
# 1900-01-31             four         111               21  16500.0
# 1900-02-01              six         154               19  16500.0
# 1900-02-02             four         102               24  13950.0
# 1900-02-03             five         115               18  17450.0
#             index  company   body-style  wheel-base  length engine-type  \
# ...

# %%
a = df.groupby('company')['horsepower']
a.describe()
# Out:
#                count        mean        std    min    25%    50%     75%  \
# company
# alfa-romero      3.0  125.333333  24.826062  111.0  111.0  111.0  132.50
# audi             4.0  109.250000   5.377422  102.0  108.0  110.0  111.25
# bmw              6.0  144.833333  41.363833  101.0  106.0  151.5  182.00
# chevrolet        3.0   62.666667  12.701706   48.0   59.0   70.0   70.00
# dodge            2.0   68.000000   0.000000   68.0   68.0   68.0   68.00
# honda            3.0   92.333333  14.153916   76.0   88.0  100.0  100.50
# isuzu            3.0   72.666667   4.618802   70.0   70.0   70.0   74.00
# jaguar           3.0  204.666667  49.652123  176.0  176.0  176.0  219.00
# mazda            5.0   75.400000  14.415270   68.0   68.0   68.0   72.00
# mercedes-benz    4.0  153.500000  35.218366  123.0  123.0  153.5  184.00
# mitsubishi       4.0   78.000000  11.547005   68.0   68.0   78.0   88.00
# nissan           5.0   82.800000  39.156098   55.0   69.0   69.0   69.00
# ...
