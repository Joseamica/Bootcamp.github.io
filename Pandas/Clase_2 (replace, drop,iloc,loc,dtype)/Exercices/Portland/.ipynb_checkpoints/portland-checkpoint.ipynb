# %%
# Import Dependencies
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Reference the file where the CSV is locatedd
df = pd.read_csv('portland.csv', delimiter=",")
df.head()

# Import the data into a Pandas DataFrame
for i in df.columns:
    print(i)
# Out:
#                     Address  Case Number Crime Against     Neighborhood  \
# 0                       NaN  17-X4762181        Person              NaN
# 1                       NaN  17-X4757824      Property       Centennial
# 2  200 BLOCK OF SE 78TH AVE    17-900367      Property       Montavilla
# 3                       NaN  17-X4748982      Property  Southwest Hills
# 4                       NaN  17-X4748982      Property  Southwest Hills
#
#    Number of Records Occur Date Occur Month Year  Occur Time  \
# 0                  1     1/1/96           1/1/96         800
# 1                  1    1/20/00           1/1/00        1615
# 2                  1    12/1/03          12/1/03         800
# 3                  1     1/1/10           1/1/10           0
# 4                  1     1/1/10           1/1/10           0
#
#    Offense Category  Offense Count                             Offense Type  \
# 0      Sex Offenses              1                                     Rape
# ...

# %%
# look for missing values
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b77caa5ed054> in <module>
#       1 # look for missing values
# ----> 2 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
# drop null rows
df_cleaned = df.dropna()
# Out:
# Address              0
# Case Number          0
# Crime Against        0
# Neighborhood         0
# Number of Records    0
# Occur Date           0
# Occur Month Year     0
# Occur Time           0
# Offense Category     0
# Offense Count        0
# Offense Type         0
# Open Data Lat        0
# Open Data Lon        0
# Open Data X          0
# Open Data Y          0
# Report Date          0
# Report Month Year    0
# dtype: int64

# %%
# verify counts
df_cleaned.isnull().sum()
# Out:
# Address              0
# Case Number          0
# Crime Against        0
# Neighborhood         0
# Number of Records    0
# Occur Date           0
# Occur Month Year     0
# Occur Time           0
# Offense Category     0
# Offense Count        0
# Offense Type         0
# Open Data Lat        0
# Open Data Lon        0
# Open Data X          0
# Open Data Y          0
# Report Date          0
# Report Month Year    0
# dtype: int64

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
df_cleaned.head(10)
# Out:
#                           Address Case Number Crime Against   Neighborhood  \
# 2        200 BLOCK OF SE 78TH AVE   17-900367      Property     Montavilla
# 5    5400 BLOCK OF NE MALLORY AVE   17-900129      Property           King
# 6       5000 BLOCK OF NE 19TH AVE   17-901079      Property         Vernon
# 7       5000 BLOCK OF NE 19TH AVE   17-901079      Property         Vernon
# 8       12000 BLOCK OF SE PINE ST   17-900253      Property      Hazelwood
# 9       12000 BLOCK OF SE PINE ST   17-900253      Property      Hazelwood
# 10    12200 BLOCK OF N JANTZEN DR    17-11435      Property  Hayden Island
# 11      1600 BLOCK OF NE 148TH PL   17-901114      Property         Wilkes
# 12  12800 BLOCK OF NE AIRPORT WAY    17-30672      Property          Argay
# 15      800 BLOCK OF N WEBSTER ST   17-901179      Property       Humboldt
#
#     Number of Records Occur Date Occur Month Year  Occur Time  \
# 2                   1    12/1/03          12/1/03         800
# ...

# %%
# Combine similar offenses
similar_offenses_df = df_cleaned['Offense Type'].value_counts()
theft = df_cleaned['Offense Type'] = df_cleaned['Offense Type'].replace(
    {'Theft From Motor Vehicle': 'Theft', 'Motor Vehicle Theft': 'Theft', 'Stolen Property Offenses': 'Theft', 'Identity Theft': 'Theft','Robbery': 'Theft'})
similar_offenses_df
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# Theft                                          14095
# All Other Larceny                               4558
# Vandalism                                       3863
# Burglary                                        2824
# Shoplifting                                     2259
# Simple Assault                                  1216
# Drug/Narcotic Violations                        1095
# Theft of Motor Vehicle Parts or Accessories     1073
# Intimidation                                     900
# Theft From Building                              895
# False Pretenses/Swindle/Confidence Game          870
# ...

# %%
# Check to see if you comnbined similar offenses correctly in "Offense Type".

# %%
# Create a new DataFrame that looks into a specific neighborhood
df_neightborhood_king = df_cleaned.loc[df_cleaned['Neighborhood']== 'King']
df_neightborhood_king
# Out:
#                                                  Address Case Number  \
# 5                           5400 BLOCK OF NE MALLORY AVE   17-900129
# 390          5500 BLOCK OF NE MARTIN LUTHER KING JR BLVD     17-9250
# 611                           900 BLOCK OF NE ALBERTA ST   17-900046
# 708                             NE 6TH AVE / NE BEECH ST     17-1842
# 715                          1400 BLOCK OF NE ALBERTA ST   17-900118
# 896          4500 BLOCK OF NE MARTIN LUTHER KING JR BLVD     17-3877
# 1022                         500 BLOCK OF NE SKIDMORE ST   17-900234
# 1139         5900 BLOCK OF NE MARTIN LUTHER KING JR BLVD     17-6026
# 1407                         1000 BLOCK OF NE ALBERTA ST     17-7902
# 1416         5900 BLOCK OF NE MARTIN LUTHER KING JR BLVD     17-7688
# 2005                            400 BLOCK OF NE GOING ST   17-900562
# 2048                           100 BLOCK OF NE JESSUP ST    17-13750
# 2133       NE MARTIN LUTHER KING JR BLVD / NE ALBERTA ST    17-14643
# ...
