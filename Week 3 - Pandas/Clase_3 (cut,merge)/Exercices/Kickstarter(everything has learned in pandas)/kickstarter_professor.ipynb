# %%
import pandas as pd

# %%
# The path to our CSV file
file = "Resources/KickstarterData.csv"

# Read our Kickstarter data into pandas
df = pd.read_csv(file)
df.head()
# Out:
#            id                                              photo  \
# 0  1645666704  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1   874638240  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2   247074984  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3  1941196813  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4   421961595  {"small":"https://ksr-ugc.imgix.net/assets/012...
#
#                                                 name  \
# 0  The Class Act Players Theatre Company Presents...
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...
# 2                                                RUN
# 3  9th International Meeting of Youth Theatre sap...
# 4                        Get Conti to the Ed Fringe!
#
#                                                blurb    goal  pledged  \
# 0  The Class Act Players put on another one of th...  1500.0   2925.0
# 1  A brand new play about love and entitlement, b...  2500.0   2936.0
# 2  Yonni's pissed off in a world filled with scho...  1000.0   1200.0
# 3  27. April bis 1. Mai 2016 in Brixen/Südtirol/I...  2000.0   2135.0
# 4  The Italia Conti 2nd years are going to Ed Fri...  1000.0   1250.0
#
#         state                                               slug  \
# 0  successful  the-class-act-players-theatre-company-presents...
# 1  successful  mr-incredible-by-camilla-whitehill-vault-festival
# 2  successful                                             run-10
# 3  successful  9th-international-meeting-of-youth-theatre-sap...
# 4  successful                         get-conti-to-the-ed-fringe
#
#    disable_communication country  ...  \
# 0                  False      US  ...
# 1                  False      GB  ...
# 2                  False      GB  ...
# 3                  False      IT  ...
# 4                  False      GB  ...
#
#                                             location  \
# 0  {"country":"US","urls":{"web":{"discover":"htt...
# 1  {"country":"GB","urls":{"web":{"discover":"htt...
# 2  {"country":"GB","urls":{"web":{"discover":"htt...
# 3  {"country":"IT","urls":{"web":{"discover":"htt...
# 4  {"country":"GB","urls":{"web":{"discover":"htt...
#
#                                             category  \
# 0  {"urls":{"web":{"discover":"http://www.kicksta...
# 1  {"urls":{"web":{"discover":"http://www.kicksta...
# 2  {"urls":{"web":{"discover":"http://www.kicksta...
# 3  {"urls":{"web":{"discover":"http://www.kicksta...
# 4  {"urls":{"web":{"discover":"http://www.kicksta...
#
#                                              profile  spotlight  \
# 0  {"background_image_opacity":0.8,"should_show_f...       True
# 1  {"background_image_opacity":0.8,"should_show_f...       True
# 2  {"background_image_opacity":0.8,"should_show_f...       True
# 3  {"background_image_opacity":0.8,"should_show_f...       True
# 4  {"background_image_opacity":0.8,"should_show_f...       True
#
#                                                 urls  \
# 0  {"web":{"project":"https://www.kickstarter.com...
# 1  {"web":{"project":"https://www.kickstarter.com...
# 2  {"web":{"project":"https://www.kickstarter.com...
# 3  {"web":{"project":"https://www.kickstarter.com...
# 4  {"web":{"project":"https://www.kickstarter.com...
#
#                                           source_url  friends  is_starred  \
# 0  https://www.kickstarter.com/discover/categorie...      NaN         NaN
# 1  https://www.kickstarter.com/discover/categorie...      NaN         NaN
# 2  https://www.kickstarter.com/discover/categorie...      NaN         NaN
# 3  https://www.kickstarter.com/discover/categorie...      NaN         NaN
# 4  https://www.kickstarter.com/discover/categorie...      NaN         NaN
#
#    is_backing  permissions
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
#
# [5 rows x 33 columns]

# %%
# Get a list of all of our columns for easy reference
df.columns
# Out:
# Index(['id', 'photo', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug',
#        'disable_communication', 'country', 'currency', 'currency_symbol',
#        'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at',
#        'launched_at', 'staff_pick', 'is_starrable', 'backers_count',
#        'static_usd_rate', 'usd_pledged', 'creator', 'location', 'category',
#        'profile', 'spotlight', 'urls', 'source_url', 'friends', 'is_starred',
#        'is_backing', 'permissions'],
#       dtype='object')

# %%
# Extract "name", "goal", "pledged", "state", "country", "staff_pick",
# "backers_count", and "spotlight"
reduced_kickstarter_df = df.loc[:, ["name", "goal", "pledged",
                                    "state", "country", "staff_pick", "backers_count", "spotlight"]]
reduced_kickstarter_df
# Out:
#                                                    name     goal   pledged  \
# 0     The Class Act Players Theatre Company Presents...   1500.0   2925.00
# 1     MR INCREDIBLE by Camilla Whitehill - VAULT Fes...   2500.0   2936.00
# 2                                                   RUN   1000.0   1200.00
# 3     9th International Meeting of Youth Theatre sap...   2000.0   2135.00
# 4                           Get Conti to the Ed Fringe!   1000.0   1250.00
# 5     Somebody Out There Loves Me @ Edinburgh Fringe...   1100.0   1100.00
# 6              Stand Up & Slam! at the Edinburgh Fringe   1500.0   1605.00
# 7          Edinburgh Fringe Tour of Two Modern Classics   2550.0   2552.00
# 8                               Forefront Festival 2015   7200.0   7230.00
# 9     Tangerine Theatre presents GODDESS by Serena H...   1200.0   1625.00
# 10                      I Would... get us to Edinburgh!    700.0    745.00
# 11                                Hamlet the Hip-Hopera   9747.0  10103.00
# 12                              In The Company Of Women   1987.0   1987.00
# 13    Interview with a Genius and Half Arsed Flyerer...    230.0    230.00
# 14                                            Pride Con  15000.0  15110.00
# 15        En Garde Arts Emerging Artists Festival BOSSS  10000.0  10306.00
# 16     Stacy Queen & Berri Juicy @ Fringe Festival 2016    500.0    610.00
# 17                    My Life in Michaels, a short play   1200.0   1265.00
# 18                                 African Celebration!  40000.0  40219.00
# 19                    MSGA Junior Theater Festival 2016   1000.0   1300.00
# 20    A Kingdom for a Stage!              - Much Ado...   5000.0   6475.00
# 21    BE BETTER: Urban Foxes - Edinburgh Festival (F...   1300.0   1644.00
# 22                   Born in Burnley, Made in Edinburgh   1000.0   1132.00
# 23                                                SOCKS   1000.0   1420.00
# 24            CASA Latin American Theatre Festival 2015   7500.0   7503.77
# 25                                            Scattered   2500.0   2501.00
# 26    EUTCo presents scenes from Tom Wells' 'The Kit...    700.0    806.00
# 27           Two Thirds @ the Edinburgh Fringe Festival    800.0    800.00
# 28       The Curiositorium at the Edinburgh Fringe 2015   1500.0   1936.99
# 29                         ANTIGONE: An Arabian Tragedy    300.0    375.00
# ...                                                 ...      ...       ...
# 4090            Thérèse Raquin at The Courtyard Theatre    250.0    250.00
# 4091  The Honeymoon is Over - An Original Play by Za...    900.0   1175.00
# 4092    "Lucy & Vincente" A New Play about Lucille Ball   3000.0   3319.00
# 4093                                   The Lower Depths   2000.0   2287.00
# 4094  Green Light Productions produces theatre creat...   5000.0   5024.00
# 4095                            Bluebirds by Joe Brondo   7000.0   7365.00
# 4096  "Lifted" - The Theatre Shed's 10 Year Annivers...   2000.0   3100.00
# 4097  Dandelion Theatre: 'Body Awareness' by Annie B...   2000.0   2041.00
# 4098                     Go People does 'Almost, Maine'   5000.0   5430.00
# 4099        One-Man Show: "The Book Of oded, Chapter 2"  10000.0  10299.00
# 4100    The Seagull Project Presents: The Three Sisters  20000.0  21573.00
# 4101                       A Hard Rain - New York Debut   3000.0   3133.00
# 4102                                     Secret Diaries   2500.0   2867.99
# 4103                                            We Rise   1500.0   1800.00
# 4104                   Verdigris - A Play by Jim Beaver  35000.0  56079.83
# 4105        The Butterfingers Angel... [By The Mummers]   8000.0   8010.00
# 4106            Lord of the Flies - Syracuse University   4000.0   4443.00
# 4107                               Beauty and the Beast   4500.0   4592.00
# 4108                    A Few Brave Men: The Chosen Few   5000.0   5000.00
# 4109                                    Going To Market   2000.0   2100.00
# 4110  LIBERTY! EQUALITY! AND FIREWORKS!... A Civil R...   3000.0   3506.00
# 4111   EUTCo presents 'One Flew Over the Cuckoo's Nest'   1000.0   1330.00
# 4112                                            CHILD Z   4000.0   4545.00
# 4113                 Saxon Court at Southwark Playhouse   1500.0   1950.00
# 4114                       The Village - one woman show   5000.0   5343.00
# 4115            Bring Love's Labour's Lost to Minnesota  25000.0  25388.00
# 4116                                              Score    300.0    340.00
# 4117  "The Santaland Diaries" by David Sedaris in Lo...   6000.0   7140.00
# 4118    REBATEnsemble Presents: ICONS - The Martin Show    300.0    312.00
# 4119                                    Licensed To Ill   3000.0   3084.00
#
#            state country  staff_pick  backers_count  spotlight
# 0     successful      US       False             17       True
# 1     successful      GB        True             15       True
# 2     successful      GB       False             30       True
# 3     successful      IT       False             24       True
# 4     successful      GB       False             28       True
# 5     successful      GB       False             41       True
# 6     successful      GB       False             49       True
# 7     successful      GB       False             17       True
# 8     successful      US       False             68       True
# 9     successful      GB       False             34       True
# 10    successful      GB       False             27       True
# 11    successful      US        True            132       True
# 12    successful      GB       False             17       True
# 13    successful      GB       False              8       True
# 14    successful      US       False             60       True
# 15    successful      US        True             80       True
# 16    successful      AU       False             12       True
# 17    successful      US       False             19       True
# 18    successful      NO       False             58       True
# 19    successful      US       False             17       True
# 20    successful      US       False            105       True
# 21    successful      GB       False             34       True
# 22    successful      GB       False             51       True
# 23    successful      CA       False             29       True
# 24    successful      GB        True            117       True
# 25    successful      GB       False             28       True
# 26    successful      GB       False             22       True
# 27    successful      GB       False              9       True
# 28    successful      GB       False             61       True
# 29    successful      GB       False              5       True
# ...          ...     ...         ...            ...        ...
# 4090  successful      GB       False             22       True
# 4091  successful      US       False             12       True
# 4092  successful      US       False             43       True
# 4093  successful      US       False             26       True
# 4094  successful      US       False             41       True
# 4095  successful      US        True             75       True
# 4096  successful      GB       False             78       True
# 4097  successful      US       False             23       True
# 4098  successful      GB        True            100       True
# 4099  successful      US       False            162       True
# 4100  successful      US        True            202       True
# 4101  successful      US       False             28       True
# 4102  successful      GB       False             95       True
# 4103  successful      US       False             31       True
# 4104  successful      US        True            930       True
# 4105  successful      US       False            113       True
# 4106  successful      US       False             65       True
# 4107  successful      GB       False             63       True
# 4108  successful      US       False             28       True
# 4109  successful      US       False             41       True
# 4110  successful      US       False             35       True
# 4111  successful      GB       False             31       True
# 4112  successful      GB       False            114       True
# 4113  successful      GB        True             51       True
# 4114  successful      CA       False             72       True
# 4115  successful      US        True            213       True
# 4116  successful      GB       False             17       True
# 4117  successful      US       False            108       True
# 4118  successful      US       False              6       True
# 4119  successful      GB       False             78       True
#
# [4120 rows x 8 columns]

# %%
# Remove projects that made no money at all
reduced_kickstarter_df = reduced_kickstarter_df.loc[(
    reduced_kickstarter_df["pledged"] > 0)]
reduced_kickstarter_df.head()
# Out:
#                                                 name    goal  pledged  \
# 0  The Class Act Players Theatre Company Presents...  1500.0   2925.0
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...  2500.0   2936.0
# 2                                                RUN  1000.0   1200.0
# 3  9th International Meeting of Youth Theatre sap...  2000.0   2135.0
# 4                        Get Conti to the Ed Fringe!  1000.0   1250.0
#
#         state country  staff_pick  backers_count  spotlight
# 0  successful      US       False             17       True
# 1  successful      GB        True             15       True
# 2  successful      GB       False             30       True
# 3  successful      IT       False             24       True
# 4  successful      GB       False             28       True

# %%
# Collect only those projects that were hosted in the US.

# Create a list of the columns
columns = [
    "name", "goal", "pledged", "state", 
    "country", "staff_pick", "backers_count", "spotlight"]

#  Create a new df for "US" with the columns. 
hosted_in_us = reduced_kickstarter_df.loc[reduced_kickstarter_df["country"] == "US",  columns]
hosted_in_us.head()
# Out:
#                                                  name     goal  pledged  \
# 0   The Class Act Players Theatre Company Presents...   1500.0   2925.0
# 8                             Forefront Festival 2015   7200.0   7230.0
# 11                              Hamlet the Hip-Hopera   9747.0  10103.0
# 14                                          Pride Con  15000.0  15110.0
# 15      En Garde Arts Emerging Artists Festival BOSSS  10000.0  10306.0
#
#          state country  staff_pick  backers_count  spotlight
# 0   successful      US       False             17       True
# 8   successful      US       False             68       True
# 11  successful      US        True            132       True
# 14  successful      US       False             60       True
# 15  successful      US        True             80       True

# %%
# Create a new column that finds the average amount pledged to a project
average_donation = hosted_in_us['pledged'] / hosted_in_us['backers_count']
average_donation
# Out:
# 0       172.058824
# 8       106.323529
# 11       76.537879
# 14      251.833333
# 15      128.825000
# 17       66.578947
# 19       76.470588
# 20       61.666667
# 31      105.000000
# 32      143.181818
# 33       69.117647
# 39      167.117647
# 42       62.714286
# 43       81.975000
# 44       54.241935
# 45       65.216667
# 46       42.036765
# 47       99.131579
# 48       54.347826
# 50       93.147059
# 52       37.016129
# 54       90.130952
# 59      119.047619
# 64      229.772727
# 67       59.701493
# 73       27.133333
# 74       50.500000
# 75      106.358491
# 77       54.961165
# 79       44.426230
#            ...
# 4076    107.002075
# 4077     50.981818
# 4078     52.551020
# 4080     47.878788
# 4081    150.416667
# 4082     96.666667
# 4083    133.333333
# 4084     51.222222
# 4086     93.813433
# 4087    176.086957
# 4088     45.478261
# 4091     97.916667
# 4092     77.186047
# 4093     87.961538
# 4094    122.536585
# 4095     98.200000
# 4097     88.739130
# 4099     63.574074
# 4100    106.797030
# 4101    111.892857
# 4103     58.064516
# 4104     60.300892
# 4105     70.884956
# 4106     68.353846
# 4108    178.571429
# 4109     51.219512
# 4110    100.171429
# 4115    119.192488
# 4117     66.111111
# 4118     52.000000
# Length: 2129, dtype: float64

# %%
# Create a new column that finds the average amount pledged to a project
hosted_in_us["average_donation"] = hosted_in_us['pledged'] / \
    hosted_in_us['backers_count']

# %%
# First convert "average_donation", "goal", and "pledged" columns to float
# Then Format to go to two decimal places, include a dollar sign, and use comma notation

hosted_in_us["average_donation"] = hosted_in_us["average_donation"].astype(float).map(
    "${:,.2f}".format)
hosted_in_us["goal"] = hosted_in_us["goal"].astype(float).map("${:,.2f}".format)
hosted_in_us["pledged"] = hosted_in_us["pledged"].astype(float).map("${:,.2f}".format)

# %%
hosted_in_us.head()
# Out:
#                                                  name        goal     pledged  \
# 0   The Class Act Players Theatre Company Presents...   $1,500.00   $2,925.00
# 8                             Forefront Festival 2015   $7,200.00   $7,230.00
# 11                              Hamlet the Hip-Hopera   $9,747.00  $10,103.00
# 14                                          Pride Con  $15,000.00  $15,110.00
# 15      En Garde Arts Emerging Artists Festival BOSSS  $10,000.00  $10,306.00
#
#          state country  staff_pick  backers_count  spotlight average_donation
# 0   successful      US       False             17       True          $172.06
# 8   successful      US       False             68       True          $106.32
# 11  successful      US        True            132       True           $76.54
# 14  successful      US       False             60       True          $251.83
# 15  successful      US        True             80       True          $128.82

# %%
# Calculate the total number of backers for all US projects
hosted_in_us["backers_count"].sum()
# Out:
# 89273

# %%
# Calculate the average number of backers for all US projects
hosted_in_us["backers_count"].mean()
# Out:
# 41.931892907468296

# %%
# Collect only those US campaigns that have been picked as a "Staff Pick"
picked_by_staff = hosted_in_us.loc[hosted_in_us["staff_pick"] == True]
picked_by_staff
# Out:
#                                                    name         goal  \
# 11                                Hamlet the Hip-Hopera    $9,747.00
# 15        En Garde Arts Emerging Artists Festival BOSSS   $10,000.00
# 39                      "Poor People" at FringeNYC 2015    $5,500.00
# 44     Queen Mab's Steampunk and Fairie Street Festival    $1,300.00
# 45                   RAFT: a new play by Emily Kitchens    $7,500.00
# 47    The Spinning Wheel: a son remixes a father's r...   $20,000.00
# 50                     Bloomers Presents: LaughtHERfest    $8,000.00
# 54    Natasha Noman's Noman's Land  | Aug 5-15th Edi...    $7,000.00
# 107   Peter/Wendy goes to the 2015 Edinburgh Fringe ...   $10,000.00
# 115         La Lune de Femme goes to New Orleans Fringe    $5,000.00
# 117                               Secular Solstice 2014    $7,500.00
# 122                       Southern Shakespeare Festival    $7,500.00
# 128       Too Much Light Heads to the Edinburgh Fringe!   $15,000.00
# 136                                 And Then Came Tango    $2,000.00
# 153   The Trouble With Dead Boyfriends goes to Premi...    $4,500.00
# 194                               (Wo)men Rule Broadway   $10,000.00
# 215            The Waterman: A Forgotten Cascadian Myth    $3,500.00
# 226   TINY - A New Musical Based On The Life Of Tiny...    $7,500.00
# 228   Deaf West Theatre's Spring Awakening Tony Perf...  $200,000.00
# 252   The Wolves of Chernobyl Present Recordings & T...    $3,150.00
# 254                                   Alien Vs. Musical   $15,000.00
# 260              Help Get Street Theatre Off The Street   $15,000.00
# 264   He Knew He Would Say It (But Could He Believe ...    $5,000.00
# 276                          35MM, A Musical Exhibition    $5,000.00
# 278                           SPEAKEASY - a new musical   $13,500.00
# 286           The Monster of Phantom Lake: The Musical!    $2,500.00
# 288                      Kat Robichaud's Misfit Cabaret    $6,000.00
# 293             Spies Are Forever: A New Comedy Musical   $42,000.00
# 314                    Andina, the Opera That Never Was    $2,200.00
# 321   'What's Your Wish?'- Thicket & Thistle's Fring...    $6,750.00
# ...                                                 ...          ...
# 3660                        Toscana, or What I Remember    $4,000.00
# 3702       Catapult OYL to the next level—in Edinburgh!   $15,000.00
# 3716   Two "Gentlemen" of Verona by William Shakespeare    $2,000.00
# 3741  Honorable Men - Poor Yorick's Players 2016 Season    $1,000.00
# 3811           Orpheus Descending by Tennessee Williams   $15,500.00
# 3821           Hear Me Roar: A Season of Powerful Women    $7,000.00
# 3827           "Next Stop" - Adjusting to dating in NYC   $10,000.00
# 3828  Titus Andronicus (with an all-female cast & crew)    $2,500.00
# 3838  Keep the Art of Marionettes Alive With PUPPETW...    $5,000.00
# 3846         Shakespeare in ASL - and FREE for everyone    $2,500.00
# 3866  Celebrating 20 years of The 24 Hour Plays arou...   $35,000.00
# 3871                         THE INCREDIBLE FOX SISTERS    $8,000.00
# 3876                            Colt Coeur's 6th Season   $35,000.00
# 3883                                       The Gray Man   $10,000.00
# 3899  Good People by David Lindsay-Abaire at Waterfr...    $3,100.00
# 3926     Scrappy Shakespeare: A Midsummer Night's Dream    $3,300.00
# 3929  or, The Whale: an original stage adaptation of...   $15,000.00
# 3951  Paperhand Puppet Intervention 16th Annual Summ...   $10,000.00
# 3952  Yesterday Again, Please - A New Play by Dezi G...    $5,500.00
# 3954                              The Metronome Society    $1,500.00
# 3970                                            Macbeth    $6,000.00
# 4018           Honest Accomplice Theatre 2015-16 Season   $12,000.00
# 4049  Eyes Closed - The First In-Dream Theater Exper...   $20,000.00
# 4078                            Kapow-i GoGo at The PIT    $2,500.00
# 4081  The Hurtling Stillness. A story about angels a...    $1,800.00
# 4086             Prison Boxing: A New Play by Leah Joki   $12,200.00
# 4095                            Bluebirds by Joe Brondo    $7,000.00
# 4100    The Seagull Project Presents: The Three Sisters   $20,000.00
# 4104                   Verdigris - A Play by Jim Beaver   $35,000.00
# 4115            Bring Love's Labour's Lost to Minnesota   $25,000.00
#
#           pledged       state country  staff_pick  backers_count  spotlight  \
# 11     $10,103.00  successful      US        True            132       True
# 15     $10,306.00  successful      US        True             80       True
# 39      $5,682.00  successful      US        True             34       True
# 44      $3,363.00  successful      US        True             62       True
# 45      $7,826.00  successful      US        True            120       True
# 47     $22,602.00  successful      US        True            228       True
# 50      $9,501.00  successful      US        True            102       True
# 54      $7,571.00  successful      US        True             84       True
# 107    $12,003.00  successful      US        True             95       True
# 115     $5,519.00  successful      US        True             79       True
# 117     $8,157.01  successful      US        True            164       True
# 122     $8,202.00  successful      US        True             63       True
# 128    $15,277.00  successful      US        True            239       True
# 136     $2,001.00  successful      US        True             39       True
# 153     $4,970.00  successful      US        True             79       True
# 194    $10,034.00  successful      US        True             50       True
# 215     $3,502.50  successful      US        True             66       True
# 226     $9,591.00  successful      US        True            138       True
# 228   $211,634.17  successful      US        True           1769       True
# 252     $4,658.00  successful      US        True            125       True
# 254    $16,212.00  successful      US        True            371       True
# 260    $16,612.00  successful      US        True            119       True
# 264     $5,916.00  successful      US        True             70       True
# 276     $5,030.00  successful      US        True             35       True
# 278    $14,305.00  successful      US        True            142       True
# 286     $6,495.00  successful      US        True            103       True
# 288    $12,141.69  successful      US        True            179       True
# 293    $58,830.08  successful      US        True           1147       True
# 314     $5,076.89  successful      US        True             91       True
# 321     $6,766.83  successful      US        True            101       True
# ...           ...         ...     ...         ...            ...        ...
# 3660    $4,296.00  successful      US        True             21       True
# 3702   $15,481.00  successful      US        True            181       True
# 3716    $2,047.00  successful      US        True             39       True
# 3741    $1,312.00  successful      US        True             26       True
# 3811   $15,705.00  successful      US        True            286       True
# 3821    $7,164.00  successful      US        True             37       True
# 3827   $15,443.00  successful      US        True            145       True
# 3828    $2,804.16  successful      US        True             68       True
# 3838    $5,462.00  successful      US        True             73       True
# 3846    $3,120.00  successful      US        True             84       True
# 3866   $35,275.64  successful      US        True            269       True
# 3871    $8,227.00  successful      US        True             71       True
# 3876   $35,123.00  successful      US        True            134       True
# 3883   $11,122.00  successful      US        True            193       True
# 3899    $3,395.00  successful      US        True             74       True
# 3926    $3,315.00  successful      US        True             49       True
# 3929   $15,315.00  successful      US        True            288       True
# 3951   $12,806.00  successful      US        True            176       True
# 3952    $5,771.00  successful      US        True             88       True
# 3954    $1,661.00  successful      US        True             20       True
# 3970    $7,877.00  successful      US        True            163       True
# 4018   $12,095.00  successful      US        True            200       True
# 4049   $20,022.00  successful      US        True            119       True
# 4078    $2,575.00  successful      US        True             49       True
# 4081    $1,805.00  successful      US        True             12       True
# 4086   $12,571.00  successful      US        True            134       True
# 4095    $7,365.00  successful      US        True             75       True
# 4100   $21,573.00  successful      US        True            202       True
# 4104   $56,079.83  successful      US        True            930       True
# 4115   $25,388.00  successful      US        True            213       True
#
#      average_donation
# 11             $76.54
# 15            $128.82
# 39            $167.12
# 44             $54.24
# 45             $65.22
# 47             $99.13
# 50             $93.15
# 54             $90.13
# 107           $126.35
# 115            $69.86
# 117            $49.74
# 122           $130.19
# 128            $63.92
# 136            $51.31
# 153            $62.91
# 194           $200.68
# 215            $53.07
# 226            $69.50
# 228           $119.63
# 252            $37.26
# 254            $43.70
# 260           $139.60
# 264            $84.51
# 276           $143.71
# 278           $100.74
# 286            $63.06
# 288            $67.83
# 293            $51.29
# 314            $55.79
# 321            $67.00
# ...               ...
# 3660          $204.57
# 3702           $85.53
# 3716           $52.49
# 3741           $50.46
# 3811           $54.91
# 3821          $193.62
# 3827          $106.50
# 3828           $41.24
# 3838           $74.82
# 3846           $37.14
# 3866          $131.14
# 3871          $115.87
# 3876          $262.11
# 3883           $57.63
# 3899           $45.88
# 3926           $67.65
# 3929           $53.18
# 3951           $72.76
# 3952           $65.58
# 3954           $83.05
# 3970           $48.33
# 4018           $60.48
# 4049          $168.25
# 4078           $52.55
# 4081          $150.42
# 4086           $93.81
# 4095           $98.20
# 4100          $106.80
# 4104           $60.30
# 4115          $119.19
#
# [174 rows x 9 columns]

# %%
# Group by the state of the campaigns and see if staff picks matter (Seems to matter quite a bit)
state_groups = picked_by_staff.groupby("state")
state_groups["name"].count()
# Out:
# state
# canceled        6
# failed         21
# live            2
# successful    145
# Name: name, dtype: int64
