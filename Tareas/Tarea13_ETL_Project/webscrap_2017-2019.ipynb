# %%
import os
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url_mx = 'https://www.national-football-teams.com/country/121/2019/Mexico.html'
browser.visit(url_mx)

# %%
html = browser.html
soup = bs(html, 'html.parser')

# %%
tables = 0

# %%
type(tables)
# Out:
# int

# %%
countries = ['Brazil', 'Mexico', 'France']
years = np.arange(2017, 2020)


for country in countries:
    url_2017 = f'https://www.national-football-teams.com/country/121/2017/{country}.html'
    url_2018 = f'https://www.national-football-teams.com/country/121/2018/{country}.html'
    url_2019 = f'https://www.national-football-teams.com/country/121/2019/{country}.html'
    for i in range(1):
        select = soup.find_all('select', class_="form-control")
        if browser.url == url_2019:
            try:
                tables2019 = pd.read_html(url_2019)
                df = tables2019[0]
                df = df.droplevel(0, axis=1)
                df = df.drop(columns="Unnamed: 3_level_1")
                df = df.set_index('Name')
                tag = browser.find_by_name("year")
                tag.click()
                select_year = browser.find_by_value("2018")
                select_year.click()
                print('yes 2019')
                df
            except:
                print('algo esta mal en 2019')
        if browser.url == url_2018:
            try:
                tables2018 = pd.read_html(url_2018)
                df1 = tables2018[0]
                df1 = df1.droplevel(0, axis=1)
                df1 = df1.drop(columns="Unnamed: 3_level_1")
                df1 = df1.set_index('Name')
                browser.find_by_name("year").click()
                browser.find_by_value("2017").click()
                print('yes 2018')
                df1
            except:
                print('algo esta mal 2018')
        if browser.url == url_2017:
            try:
                tables2017 = pd.read_html(url_2017)
                df2 = tables2017[0]
                df2 = df2.droplevel(0, axis=1)
                df2 = df2.drop(columns="Unnamed: 3_level_1")
                df2 = df2.set_index('Name')
                print('yes 2017')
                df2
            except:
                print('algo esta mal 2017')
        
            
            



html_df = df.to_html('2019.html')
html_df1 = df1.to_html('2018.html')
html_df2 = df2.to_html('2017.html')
html_df = html_df.replace('\n', '')
html_df1 = html_df1.replace('\n', '')
html_df2 = html_df2.replace('\n', '')
# Out:
# yes 2019
#                                   D. o. B.              Position  \
# Name
# Ochoa, Guillermo                1985-07-13            Goalkeeper
# Orozco, Jonathan                1986-05-12            Goalkeeper
# Gudiño, Raúl                    1996-04-22            Goalkeeper
# Rodríguez, Luis                 1991-01-21            Right Back
# Álvarez, Edson                  1997-10-24           Centre Back
# Salcedo, Carlos                 1993-09-29           Centre Back
# Araujo, Néstor                  1991-08-29           Centre Back
# Reyes, Diego                    1992-09-19           Centre Back
# Moreno, Héctor                  1988-01-17           Centre Back
# Sánchez, Jorge                  1997-12-10            Right Back
# Montes, César                   1997-02-24           Centre Back
# Layún, Miguel                   1988-06-25            Right Back
# Navarro, Fernando               1989-04-18            Right Back
# ...

# %%
# !open 2019.html

# %%
import pymongo

def getData():
    conn = 'mongodb://localhost:27017'
    client = pymongo.MongoClient(conn)
    db = client.Mars
    collection = db.MarsData
    data = collection.find_one()
    return data

# %%
print(getData())
# Out:
# {'_id': ObjectId('5d6853fe1e44cf15d7bde524'), 'newsTitle': 'NASA Invites Students to Name Mars 2020 Rover', 'newsDescription': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.", 'featuredImageUrl': 'https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA19974-1920x1200.jpg', 'marsWeather': 'InSight sol 263 (2019-08-23) low -100.9ºC (-149.6ºF) high -27.2ºC (-17.0ºF)\nwinds from the SW at 4.1 m/s (9.2 mph) gusting to 18.3 m/s (40.9 mph)\npressure at 7.60 hPa', 'marsFacts': {'Value': {'Equatorial Diameter:': '6,792 km', 'Polar Diameter:': '6,752 km', 'Mass:': '6.39 × 10^23 kg (0.11 Earths)', 'Moons:': '2 (Phobos & Deimos)', 'Orbit Distance:': '227,943,824 km (1.38 AU)', 'Orbit Period:': '687 days (1.9 years)', 'Surface Temperature:': '-87 to -5 °C', 'First Record:': '2nd millennium BC', 'Recorded By:': 'Egyptian astronomers'}}, 'imageList': [{'title': 'Cerberus Hemisphere', 'img_url': 'https://astrogeology.usgs.gov/cac
# ...
