# %%
# %matplotlib inline

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.pyplot import figure
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# File to Load (Remember to change these)
city_data_to_load = "city_data.csv"
ride_data_to_load = "ride_data.csv"

city_df = pd.read_csv(city_data_to_load)
ride_df = pd.read_csv(ride_data_to_load)

# Read the City and Ride Data
df = pd.read_csv('ride_data.csv').merge(pd.read_csv('city_data.csv'))
df_merged = ride_df.merge(city_df, how='left')
df_merged.to_excel("output.xlsx")

# Display the data table for preview

df_merged.head(5)
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
urban = df_merged.set_index(df_merged['type']).loc['Urban']

# %% [markdown]
# se guardan los tipos "urban suburban etc"
# se calcula el total de los viajes hechos por ciudad
# se calcula el promedio de cobro

# %%
#urban average fares y_axis
urban = df_merged.loc[(df_merged['type'] == 'Urban')]
urban = urban.groupby(['city'])
urban_fare_avg = urban['fare'].mean()
#urban total rides x_axis
urban_total_rides = urban['city'].count()
#axis
x_urban = urban_total_rides
y_urban = urban_fare_avg
#a
urban_total_drivers = urban['driver_count'].sum()


#suburban average fares y_axis
suburban = df_merged.loc[(df_merged['type'] == 'Suburban')]
suburban = suburban.groupby(['city'])
suburban_fare_avg = suburban['fare'].mean()
#suburban total rides x_axis
suburban_total_rides = suburban['city'].count()

#axis
x_suburban = suburban_total_rides
y_suburban = suburban_fare_avg

suburban_total_drivers = suburban['driver_count'].sum()

#rural average fares y_axis
rural = df_merged.loc[(df_merged['type'] == 'Rural')]
rural = rural.groupby(['city'])
rural_fare_avg = rural['fare'].mean()
#suburban total rides x_axis
rural_total_rides = rural['city'].count()
#axis
x_rural = rural_total_rides
y_rural = rural_fare_avg

#
rural_total_drivers = rural['driver_count'].sum()



#axis limits
plt.ylim(19, 44)
plt.xlim(0,41)

plt.scatter(x_urban, y_urban, marker="o", facecolors="orange", edgecolors="black", 
            s=urban_total_drivers, alpha=0.75, label='Urban')
plt.scatter(x_suburban, y_suburban, marker="o", facecolors="blue", edgecolors="black", 
            s=suburban_total_drivers, alpha=0.75, label ='Suburban')
plt.scatter(x_rural, y_rural, marker="o", facecolors="yellow", edgecolors="black", 
            s=rural_total_drivers, alpha=0.75, label ='Rural')
plt.legend(loc="best")
plt.grid()

plt.title('Pyber Ride Sharing Data (2016)')
plt.xlabel('Total Number of Rides(Per City)')
plt.ylabel('Average Fare ($)')
# Out:
#                       date  fare  ride_id  driver_count  type
# city
# Amandaburgh             18    18       18            18    18
# Barajasview             22    22       22            22    22
# Carriemouth             27    27       27            27    27
# Christopherfurt         27    27       27            27    27
# Deanville               19    19       19            19    19
# East Kaylahaven         29    29       29            29    29
# Erikaland               12    12       12            12    12
# Grahamburgh             25    25       25            25    25
# Huntermouth             24    24       24            24    24
# Hurleymouth             28    28       28            28    28
# Jerryton                25    25       25            25    25
# Johnton                 21    21       21            21    21
# Joneschester            25    25       25            25    25
# Justinberg              30    30       30            30    30
# Karenberg               17    17       17            17    17
# Karenside               28    28       28            28    28
# Lake Danielberg         26    26       26            26    26
# Lake Jonathanshire      24    24       24            24    24
# Lake Scottton           24    24       24            24    24
# Leahton                 21    21       21            21    21
# Liumouth                33    33       33            33    33
# Loganberg               28    28       28            28    28
# Martinezhaven           24    24       24            24    24
# New Jacobville          18    18       18            18    18
# New Kimberlyborough     30    30       30            30    30
# New Paulton             19    19       19            19    19
# New Paulville           22    22       22            22    22
# North Barbara           22    22       22            22    22
# North Jasmine           30    30       30            30    30
# North Jason             35    35       35            35    35
# ...                    ...   ...      ...           ...   ...
# Port Johnbury           22    22       22            22    22
# Port Samanthamouth      25    25       25            25    25
# Raymondhaven            25    25       25            25    25
# Reynoldsfurt            19    19       19            19    19
# Richardfort             28    28       28            28    28
# Roberthaven             24    24       24            24    24
# Robertport              20    20       20            20    20
# Rodneyfort              23    23       23            23    23
# Rogerston               22    22       22            22    22
# Royland                 30    30       30            30    30
# Simpsonburgh            24    24       24            24    24
# South Evanton           31    31       31            31    31
# South Jack              19    19       19            19    19
# South Karenland         38    38       38            38    38
# South Latoya            19    19       19            19    19
# South Michelleport      31    31       31            31    31
# South Phillip           31    31       31            31    31
# Valentineton            22    22       22            22    22
# West Angela             39    39       39            39    39
# West Anthony            30    30       30            30    30
# West Christopherberg    26    26       26            26    26
# West Ericstad           18    18       18            18    18
# West Gabriel            23    23       23            23    23
# West Heidi              28    28       28            28    28
# West Josephberg         26    26       26            26    26
# West Patrickchester     16    16       16            16    16
# West Robert             31    31       31            31    31
# West Samuelburgh        25    25       25            25    25
# Williamsstad            23    23       23            23    23
# Williamsview            20    20       20            20    20
#
# [66 rows x 5 columns]
# (19, 44)
# (0, 41)
# Text(0.5, 1.0, 'Pyber Ride Sharing Data (2016)')
# Text(0.5, 0, 'Total Number of Rides(Per City)')
# Text(0, 0.5, 'Average Fare ($)')

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
total_fares = df_merged['fare'].sum()
urban_fares = (urban['fare'].sum()).sum() / total_fares * 100
suburban_fares = (suburban['fare'].sum()).sum() / total_fares * 100
rural_fares = (rural['fare'].sum()).sum() / total_fares * 100

# Build Pie Chart
total_fa = [urban_fares,rural_fares,suburban_fares]
types = ['Urban','Rural','Suburban']
explode = [0.1,0,0]
colors = ['Coral','Gold','SkyBlue']

plt.pie(total_fa, explode=explode, labels=types, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=260,)
# Save Figure
plt.axis("equal")
# Out:
# ([<matplotlib.patches.Wedge at 0x11bb44eb8>,
#   <matplotlib.patches.Wedge at 0x11bb4d898>,
#   <matplotlib.patches.Wedge at 0x11bb5b278>],
#  [Text(1.169693147981355, 0.26798869298063277, 'Urban'),
#   Text(-0.8183497488822089, 0.735053527645726, 'Rural'),
#   Text(-0.9955955489328239, -0.46774940186509, 'Suburban')],
#  [Text(0.6823210029891238, 0.15632673757203577, '62.7%'),
#   Text(-0.44637259029938664, 0.40093828780675955, '6.8%'),
#   Text(-0.543052117599722, -0.2551360373809582, '30.5%')])
# (-1.1112563362116055,
#  1.2148058462589555,
#  -1.0924589717218391,
#  1.1366907384688834)

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Type Percents
total_types = df_merged['type'].count()
urban_riders = urban_total_rides.sum() / total_types * 100
suburban_riders = suburban_total_rides.sum() / total_types * 100
rural_riders = rural_total_rides.sum() / total_types * 100

urban_riders
# Build Pie Chart
total_riders = [urban_riders,rural_riders,suburban_riders]
types = ['Urban','Rural','Suburban']
explode = [0.1,0,0]
colors = ['Coral','Gold','SkyBlue']

plt.pie(total_riders, explode=explode, labels=types, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=260,)
# Save Figure
plt.axis("equal")
plt.title("% of Total Rides by City Type")
plt.tight_layout()
# Out:
# 68.42105263157895
# ([<matplotlib.patches.Wedge at 0x11b9d0860>,
#   <matplotlib.patches.Wedge at 0x11b9db320>,
#   <matplotlib.patches.Wedge at 0x11b9dbcc0>],
#  [Text(1.1033094885454109, 0.4719196674071382, 'Urban'),
#   Text(-1.0032493053238525, 0.4510995803225798, 'Rural'),
#   Text(-0.9263707884205817, -0.5931586317006858, 'Suburban')],
#  [Text(0.6435972016514897, 0.2752864726541639, '68.4%'),
#   Text(-0.5472268938130104, 0.24605431653958892, '5.3%'),
#   Text(-0.5052931573203173, -0.3235410718367377, '26.3%')])
# (-1.1151552225377388,
#  1.2128331839959388,
#  -1.0866301662689613,
#  1.1534623888620021)
# Text(0.5, 1.0, '% of Total Rides by City Type')

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
total_drivers = urban['type'].count()
total_drivers
urban_drivers = urban['driver_count'].sum().sum()
suburban_drivers = (suburban['driver_count'].sum()).sum() / total_drivers * 100
rural_drivers = (rural['driver_count'].sum()).sum() / total_drivers * 100
urban_drivers

# Build Pie Chart
total_drivers = [urban_drivers,rural_drivers,suburban_drivers]
types = ['Urban','Rural','Suburban']
explode = [0.1,0,0]
colors = ['Coral','Gold','SkyBlue']

plt.pie(total_drivers, explode=explode, labels=types, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=220,)
# Save Figure
plt.axis("equal")
# Build Pie Charts
plt.title("% of Total Drivers by City Type")
# Save Figure
plt.tight_layout()
# Out:
# city
# Amandaburgh             18
# Barajasview             22
# Carriemouth             27
# Christopherfurt         27
# Deanville               19
# East Kaylahaven         29
# Erikaland               12
# Grahamburgh             25
# Huntermouth             24
# Hurleymouth             28
# Jerryton                25
# Johnton                 21
# Joneschester            25
# Justinberg              30
# Karenberg               17
# Karenside               28
# Lake Danielberg         26
# Lake Jonathanshire      24
# Lake Scottton           24
# Leahton                 21
# Liumouth                33
# Loganberg               28
# Martinezhaven           24
# New Jacobville          18
# New Kimberlyborough     30
# New Paulton             19
# New Paulville           22
# North Barbara           22
# North Jasmine           30
# North Jason             35
#                         ..
# Port Johnbury           22
# Port Samanthamouth      25
# Raymondhaven            25
# Reynoldsfurt            19
# Richardfort             28
# Roberthaven             24
# Robertport              20
# Rodneyfort              23
# Rogerston               22
# Royland                 30
# Simpsonburgh            24
# South Evanton           31
# South Jack              19
# South Karenland         38
# South Latoya            19
# South Michelleport      31
# South Phillip           31
# Valentineton            22
# West Angela             39
# West Anthony            30
# West Christopherberg    26
# West Ericstad           18
# West Gabriel            23
# West Heidi              28
# West Josephberg         26
# West Patrickchester     16
# West Robert             31
# West Samuelburgh        25
# Williamsstad            23
# Williamsview            20
# Name: type, Length: 66, dtype: int64
# 59602
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-2f53033d8df9> in <module>
#      14
#      15 plt.pie(total_drivers, explode=explode, labels=types, colors=colors,
# ---> 16         autopct="%1.1f%%", shadow=True, startangle=220,)
#      17 # Save Figure
#      18 plt.axis("equal")
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2801         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2802         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2803         data is not None else {}))
#    2804
#    2805
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2797         """
#    2798         self.set_aspect('equal')
# -> 2799         x = np.array(x, np.float32)
#    2800
#    2801         sx = x.sum()
#
# ValueError: setting an array element with a sequence.

# %%
# Show Figure
plt.show()

# %%
´´´´´´´´´´´´´´´                                                                                                         bnm
