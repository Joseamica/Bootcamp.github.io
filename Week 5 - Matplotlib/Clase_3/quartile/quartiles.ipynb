# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
from stats import median
import numpy as np

# %%
### Data Points
arr = np.array([2.3, 10.2,11.2, 12.3, 14.5, 14.6, 15.0, 15.1, 19.0, 24.0])
arr
# Out:
# array([ 2.3, 10.2, 11.2, 12.3, 14.5, 14.6, 15. , 15.1, 19. , 24. ])

# %%
# Find the median
arr_median = np.median(arr)
arr_median
# Out:
# 14.55

# %%
# Use numpy to create quartiles
lower_quartile = np.percentile(arr,25)
high_quartile = np.percentile(arr,75)

iq = high_quartile-lower_quartile
iq
# Out:
# 3.6000000000000014

# %%
# Print the quartiles

# %%
# Calculate the interquartile range
iq
# Out:
# 3.6000000000000014

# %%
# Find lower boundary
# Q1 - 1.5 * IQR
lower_boundary = lower_quartile - 1.5 * iq
lower_boundary
# Out:
# 6.074999999999996

# %%
# Find upper boundary
# Q3 + 1.5 * IQR

upper_boundary = high_quartile + 1.5 * iq
upper_boundary
# Out:
# 20.475

# %%
# Check for any lower outliers
np.sort(arr)
# Out:
# array([ 2.3, 10.2, 11.2, 12.3, 14.5, 14.6, 15. , 15.1, 19. , 24. ])

# %%
# Check for any upper outliers
np.sort(arr)
upper_outliers = arr[-1]

# %%
# Create box plot
plt.boxplot(arr, autorange=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x119fcf470>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x119fcfb00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x119fcf080>],
#  'medians': [<matplotlib.lines.Line2D at 0x119fcff28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x119ff4518>],
#  'means': []}
